# %%
from pathlib import Path
import sys

import numpy as np
import pandas as pd

# Assume this notebook is in universal-anomaly-intelligence/notebooks
project_root = Path('..').resolve()
print('Project root:', project_root)

src_path = project_root / 'src'
if str(src_path) not in sys.path:
    sys.path.append(str(src_path))

from uais.data.load_fraud_data import load_fraud_data
# Out:
# Project root: /Users/pratik_n/Desktop/MyComputer/universal-anomaly-intelligence

# %%
print('Folders in project root:')
for p in project_root.iterdir():
    if p.is_dir():
        print(' -', p.name)

fraud_raw_dir = project_root / 'data' / 'raw' / 'fraud'
print('Fraud raw directory:', fraud_raw_dir)
print('Exists:', fraud_raw_dir.exists())

if fraud_raw_dir.exists():
    print('Files in data/raw/fraud:')
    for f in fraud_raw_dir.iterdir():
        print(' -', f.name)
# Out:
# Folders in project root:
#  - config
#  - deploy
#  - experiments
#  - tests
#  - docs
#  - dashboard
#  - configs
#  - .venv
#  - scripts
#  - .github
#  - venv
#  - .venv-macos
#  - .git
#  - data
#  - notebooks
#  - reports
#  - src
# Fraud raw directory: /Users/pratik_n/Desktop/MyComputer/universal-anomaly-intelligence/data/raw/fraud
# Exists: True
# Files in data/raw/fraud:
#  - paysim
#  - creditcard.csv

# %%
df_raw = load_fraud_data()
print('Raw fraud data shape:', df_raw.shape)
df_raw.head()
# Out:
# Raw fraud data shape: (6647427, 42)
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...  type  amount  nameOrig  oldbalanceOrg  \
# 0  0.098698  0.363787  ...   NaN     NaN       NaN            NaN
# 1  0.085102 -0.255425  ...   NaN     NaN       NaN            NaN
# 2  0.247676 -1.514654  ...   NaN     NaN       NaN            NaN
# 3  0.377436 -1.387024  ...   NaN     NaN       NaN            NaN
# 4 -0.270533  0.817739  ...   NaN     NaN       NaN            NaN
#
#    newbalanceOrig  nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 0             NaN       NaN             NaN             NaN      NaN
# 1             NaN       NaN             NaN             NaN      NaN
# 2             NaN       NaN             NaN             NaN      NaN
# 3             NaN       NaN             NaN             NaN      NaN
# 4             NaN       NaN             NaN             NaN      NaN
#
#    isFlaggedFraud
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#
# [5 rows x 42 columns]
